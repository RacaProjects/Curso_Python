# %% [markdown]
# <a href="https://colab.research.google.com/github/RacaProjects/Curso_Python/blob/main/Modelo_aprendizaje_supervisado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Modelo de aprendizaje supervisado:regresion lineal**
#
# Curso Python
#
# UniCafam
#
# Estudiante: Raul Andres Casanova Porras
#
# Docente: Niculas Mojica
#
#
#
# ---

# %% [markdown]
# Objetivo: generar un modelo que de como resultado una linea que pueda predecir el comportamiento de los salarios con respecto a los años de antiguedad

# %%
# Instalar librerias

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Cargar dataset
dataset = pd.read_csv("/content/sample_data/Salary_Data.csv")

dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
# Esta es la asignacion

X = dataset.iloc[:, :-1].values # Años de experiencia
y = dataset.iloc[:, -1].values # Salario

# %% [markdown]
# Division de conjunto de datos entre entrenamiento y pruebas

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3, random_state = 0)

# %% [markdown]
# Entrenamiento del modelo de regresion lineal

# %%
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predecir los resultados del conjunto de prueba

# %%
y_test = regressor.predict(X_test)

# %% [markdown]
# Resultados

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, regressor.predict(X_train), color = 'blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
